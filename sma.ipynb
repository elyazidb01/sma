# %%
import tiktoken
tokenizer = tiktoken.encoding_for_model("gpt-3.5-turbo")
print(tokenizer.name)


prompt = "You're an expert assistant in the field of IT Development"
tokens = tokenizer.encode(prompt)
print(tokens)
print(len(tokens))

for token in tokens:
    t = tokenizer.decode_single_token_bytes(token).decode('utf-8')
    print(f"{token}: {t}")
# Out:
# cl100k_base
# [2675, 2351, 459, 6335, 18328, 304, 279, 2115, 315, 8871, 11050]
# 11
# 2675: You
# 2351: 're
# 459:  an
# 6335:  expert
# 18328:  assistant
# 304:  in
# 279:  the
# 2115:  field
# 315:  of
# 8871:  IT
# 11050:  Development
